# %%
import pandas as pd

# Load the dataset
file_path = ('/Users/pranjalts/Desktop/RESEARCH/HALE/HALE/dataset/merge.csv')  
data = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
missing_values = data.isnull().sum()
print("Missing values:")
print(missing_values)
# Out:
# Missing values:
# Period                                                                                                                                                        0
# ParentLocation                                                                                                                                                0
# Location                                                                                                                                                      0
# Dim1                                                                                                                                                          0
# HALE_Birth                                                                                                                                                    0
# HALE_60                                                                                                                                                       0
# infant mortality rate (between birth and 11 months per 1000 live births)                                                                                     66
# Age-standardized estimates of current tobacco use, tobacco smoking and cigarette smoking (Tobacco control: Monitor)                                        8871
# Age-standardized suicide rates (per 100 000 population)                                                                                                    1230
# Alcohol, total per capita (15+ years) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)                                                         852
# Probability of dying between the exact ages 30 and 70 years from cardiovascular diseases, cancer, diabetes, or chronic respiratory diseases (SDG 3.4.1)    1230
# Estimates of rate of homicides (per 100 000 population)                                                                                                    1230
# Mean Total Cholesterol (crude estimate)                                                                                                                    1836
# Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)                                                      0
# Prevalence of obesity among adults, BMI ³ 30 (age-standardized estimate) (%)                                                                                 66
# Prevalence of raised blood pressure among adults aged 30-79 years                                                                                          1110
# dtype: int64

# %%
#Filter the data for the period 2000-2019
data_filtered = data[(data['Period'] >= 2000) & (data['Period'] <= 2019)]
#Drop columns with more than 60% missing values
threshold = 0.6 * len(data_filtered)  # 60% threshold
data_filtered_cleaned = data_filtered.dropna(thresh=threshold, axis=1)

# %%
#remaining missing values
missing_values = data_filtered_cleaned.isnull().sum()
print("Missing values after filter:")
print(missing_values)
# Out:
# Missing values after filter:
# Period                                                                                                                                                       0
# ParentLocation                                                                                                                                               0
# Location                                                                                                                                                     0
# Dim1                                                                                                                                                         0
# HALE_Birth                                                                                                                                                   0
# HALE_60                                                                                                                                                      0
# infant mortality rate (between birth and 11 months per 1000 live births)                                                                                    60
# Age-standardized suicide rates (per 100 000 population)                                                                                                    120
# Alcohol, total per capita (15+ years) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)                                                        282
# Probability of dying between the exact ages 30 and 70 years from cardiovascular diseases, cancer, diabetes, or chronic respiratory diseases (SDG 3.4.1)    120
# Estimates of rate of homicides (per 100 000 population)                                                                                                    120
# Mean Total Cholesterol (crude estimate)                                                                                                                    726
# Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)                                                     0
# Prevalence of obesity among adults, BMI ³ 30 (age-standardized estimate) (%)                                                                                60
# Prevalence of raised blood pressure among adults aged 30-79 years                                                                                            0
# dtype: int64

# %%
# Backward fill for missing values ONLY in the year 2000
# Isolate rows for 2000 and apply backward fill for 2000 using future data from the same country
for country in data_filtered_cleaned['Location'].unique():
    country_data = data_filtered_cleaned[data_filtered_cleaned['Location'] == country]
    country_2000_data = country_data[country_data['Period'] == 2000]
    
    if country_2000_data.isnull().values.any():  # Check if there are missing values
        # Get the next available data after 2000 for this country
        future_data = country_data[country_data['Period'] > 2000].sort_values('Period')
        
        # Fill missing values in 2000 with the first available future data
        if not future_data.empty:
            data_filtered_cleaned.loc[(data_filtered_cleaned['Location'] == country) & 
                                      (data_filtered_cleaned['Period'] == 2000)] = (
                data_filtered_cleaned.loc[(data_filtered_cleaned['Location'] == country) & 
                                          (data_filtered_cleaned['Period'] == 2000)].fillna(future_data.iloc[0])
            )
# Round values after backward fill to ensure consistency
data_filtered_cleaned = data_filtered_cleaned.round(2)

# %%
#  Check for remaining missing values
missing_values = data_filtered_cleaned.isnull().sum()
print("Missing values after backward filling:")
print(missing_values)
# Out:
# Missing values after backward filling:
# Period                                                                                                                                                       0
# ParentLocation                                                                                                                                               0
# Location                                                                                                                                                     0
# Dim1                                                                                                                                                         0
# HALE_Birth                                                                                                                                                   0
# HALE_60                                                                                                                                                      0
# infant mortality rate (between birth and 11 months per 1000 live births)                                                                                    60
# Age-standardized suicide rates (per 100 000 population)                                                                                                    120
# Alcohol, total per capita (15+ years) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)                                                        282
# Probability of dying between the exact ages 30 and 70 years from cardiovascular diseases, cancer, diabetes, or chronic respiratory diseases (SDG 3.4.1)    120
# Estimates of rate of homicides (per 100 000 population)                                                                                                    120
# Mean Total Cholesterol (crude estimate)                                                                                                                    726
# Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)                                                     0
# Prevalence of obesity among adults, BMI ³ 30 (age-standardized estimate) (%)                                                                                60
# Prevalence of raised blood pressure among adults aged 30-79 years                                                                                            0
# dtype: int64

# %%
# Apply interpolation for the remaining missing values
data_interpolated = data_filtered_cleaned.groupby('Location').apply(lambda group: group.interpolate(method='linear'))

# Round values after interpolation
data_interpolated = data_interpolated.round(2)

# %%
# Check for remaining missing values
missing_values = data_interpolated.isnull().sum()
print("Missing values after interpolation:")
print(missing_values)
# Out:
# Missing values after interpolation:
# Period                                                                                                                                                       0
# ParentLocation                                                                                                                                               0
# Location                                                                                                                                                     0
# Dim1                                                                                                                                                         0
# HALE_Birth                                                                                                                                                   0
# HALE_60                                                                                                                                                      0
# infant mortality rate (between birth and 11 months per 1000 live births)                                                                                    60
# Age-standardized suicide rates (per 100 000 population)                                                                                                    120
# Alcohol, total per capita (15+ years) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)                                                        240
# Probability of dying between the exact ages 30 and 70 years from cardiovascular diseases, cancer, diabetes, or chronic respiratory diseases (SDG 3.4.1)    120
# Estimates of rate of homicides (per 100 000 population)                                                                                                    120
# Mean Total Cholesterol (crude estimate)                                                                                                                    180
# Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)                                                     0
# Prevalence of obesity among adults, BMI ³ 30 (age-standardized estimate) (%)                                                                                60
# Prevalence of raised blood pressure among adults aged 30-79 years                                                                                            0
# dtype: int64

# %%
# Apply global mean imputation for any remaining missing values
data_filled = data_interpolated.fillna(data_interpolated.mean(numeric_only=True))

#Round values after global mean imputation
data_filled_rounded = data_filled.round(2)

# %%
# Check for remaining missing values
missing_values = data_filled_rounded.isnull().sum()
print("Missing values after global mean imputation:")
print(missing_values)
# Out:
# Missing values after global mean imputation:
# Period                                                                                                                                                     0
# ParentLocation                                                                                                                                             0
# Location                                                                                                                                                   0
# Dim1                                                                                                                                                       0
# HALE_Birth                                                                                                                                                 0
# HALE_60                                                                                                                                                    0
# infant mortality rate (between birth and 11 months per 1000 live births)                                                                                   0
# Age-standardized suicide rates (per 100 000 population)                                                                                                    0
# Alcohol, total per capita (15+ years) consumption (in litres of pure alcohol) (SDG Indicator 3.5.2)                                                        0
# Probability of dying between the exact ages 30 and 70 years from cardiovascular diseases, cancer, diabetes, or chronic respiratory diseases (SDG 3.4.1)    0
# Estimates of rate of homicides (per 100 000 population)                                                                                                    0
# Mean Total Cholesterol (crude estimate)                                                                                                                    0
# Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)                                                   0
# Prevalence of obesity among adults, BMI ³ 30 (age-standardized estimate) (%)                                                                               0
# Prevalence of raised blood pressure among adults aged 30-79 years                                                                                          0
# dtype: int64

# %%
# Save the cleaned dataset
data_filled_rounded.to_csv('/Users/pranjalts/Desktop/RESEARCH/HALE/HALE/dataset/final1.csv', index=False)

print("Data preprocessing complete! The cleaned dataset with rounded values is saved as 'cleaned_dataset.csv'.")
# Out:
# Data preprocessing complete! The cleaned dataset with rounded values is saved as 'cleaned_dataset.csv'.
